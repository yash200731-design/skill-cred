# %% [markdown]
# <a href="https://colab.research.google.com/github/yash200731-design/skill-cred/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=["maths","english","science","c++","python"]
print(l[0],l[4])
# Out:
# maths python

# %%
d={"a":58,"b":24,"c":39,"d":94,"e":85}
for i in d:
  if d[i]>40:
    print(i)
# Out:
# a
# d
# e

# %%
s={"s1":["a",5,78,98],"s2":["b",2,45,58],"s3":["c",0.5,85,16],"s4":["d",4,88,92]}
sname=input("enter name:")
for i in s:
  for j in s[i]:
    if j==sname:
      print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7182/3511419541.py in <cell line: 0>()
#       1 s={"s1":["a",5,78,98],"s2":["b",2,45,58],"s3":["c",0.5,85,16],"s4":["d",4,88,92]}
# ----> 2 sname=input("enter name:")
#       3 for i in s:
#       4   for j in s[i]:
#       5     if j==sname:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

# Write your code below to find anomalous patterns
for i in transactions:
  if i["amount"]>5000 and i["method"]=="Gift Card":
    flagged_transactions.append(i["transaction_id"])
print(flagged_transactions)
# Out:
# ['TX102', 'TX104']

# %%
import numpy as np
a=np.array([10,20,30])
print(a)
print(a.shape)
b=np.array([[10,20,30],[40,50,60]])
print(b)
# Out:
# [10 20 30]
# (3,)
# [[10 20 30]
#  [40 50 60]]
# (2, 3)

# %%
a=np.array([78, 91, 55, 72, 40, 88,98,81,11,23,78,88,91,96])
print(a.mean())
print(a.max())
print(a.min())
print(a[a>75])
# Out:
# 70.71428571428571
# 98
# 11
# [78 91 88 98 81 78 88 91 96]

# %%
df["average"] = df[["math", "science", "english"]].mean(axis=1)
print(df[["name", "math", "science", "english", "average"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_822/2313790388.py in <cell line: 0>()
# ----> 1 df["average"] = df[["math", "science", "english"]].mean(axis=1)
#       2 print(df[["name", "math", "science", "english", "average"]])
#
# NameError: name 'df' is not defined

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-16d61cdd-e3da-4df7-9550-8efc0df2aec0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16d61cdd-e3da-4df7-9550-8efc0df2aec0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("session4_dummy_students_data.csv.xls")
print(df)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
df["average"] = df[["math", "science", "english"]].mean(axis=1)
print(df[["name", "math", "science", "english", "average"]])
# Out:
#       name  math  science  english    average
# 0    Aarav    78       84       69  77.000000
# 1     Diya    91       88       94  91.000000
# 2    Kabir    55       61       58  58.000000
# 3    Meera    72       79       81  77.333333
# 4    Rohan    40       52       47  46.333333
# 5     Sara    88       93       90  90.333333
# 6   Ishaan    64       70       66  66.666667
# 7   Ananya    95       92       89  92.000000
# 8   Vivaan    48       57       51  52.000000
# 9     Tara    83       76       85  81.333333
# 10   Arjun    67       63       72  67.333333
# 11   Nisha    74       81       79  78.000000
# 12     Dev    35       45       42  40.666667
# 13   Priya    89       86       91  88.666667
# 14   Kunal    58       54       60  57.333333
# 15    Riya    92       90       96  92.666667
# 16      Om    61       69       65  65.000000
# 17   Aditi    80       85       83  82.666667
# 18    Yash    43       49       46  46.000000
# ...

# %%
df["result"]=df["average"].apply(lambda x: "pass" if x>40 else "fail")
print(df[["name", "math", "science", "english", "average","result"]])
# Out:
#       name  math  science  english    average result
# 0    Aarav    78       84       69  77.000000   pass
# 1     Diya    91       88       94  91.000000   pass
# 2    Kabir    55       61       58  58.000000   pass
# 3    Meera    72       79       81  77.333333   pass
# 4    Rohan    40       52       47  46.333333   pass
# 5     Sara    88       93       90  90.333333   pass
# 6   Ishaan    64       70       66  66.666667   pass
# 7   Ananya    95       92       89  92.000000   pass
# 8   Vivaan    48       57       51  52.000000   pass
# 9     Tara    83       76       85  81.333333   pass
# 10   Arjun    67       63       72  67.333333   pass
# 11   Nisha    74       81       79  78.000000   pass
# 12     Dev    35       45       42  40.666667   pass
# 13   Priya    89       86       91  88.666667   pass
# 14   Kunal    58       54       60  57.333333   pass
# 15    Riya    92       90       96  92.666667   pass
# 16      Om    61       69       65  65.000000   pass
# ...

# %%
class_avg=df["average"].mean()
print(class_avg)
# Out:
# 71.35000000000001

# %%
sub=["math", "science", "english"]
for i in sub :
  print(sub)
  print(df[sub].max())
  print(df[sub].min())
# Out:
# ['math', 'science', 'english']
# math       95
# science    93
# english    96
# dtype: int64
# math       35
# science    45
# english    42
# dtype: int64
# ['math', 'science', 'english']
# math       95
# science    93
# english    96
# dtype: int64
# math       35
# science    45
# english    42
# dtype: int64
# ['math', 'science', 'english']
# math       95
# science    93
# english    96
# dtype: int64
# math       35
# science    45
# english    42
# dtype: int64

# %%
top=df["average"].max()
top_s=df[df["average"]==top]
print(top_s[["name","average"]])
# Out:
#     name    average
# 15  Riya  92.666667

# %%
low_a=df[df["attendance_percent"]<75]
print(low_a[["name","attendance_percent"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_681/668240805.py in <cell line: 0>()
# ----> 1 low_a=df[df["attendance_percent"]<75]
#       2 print(low_a[["name","attendance_percent"]])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)


print(df.head())
print(df.shape)
print(df.columns)
print(df.info())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# (1704, 6)
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# ...

# %%
print(df["year"].min(),"-",df["year"].max())
# Out:
# 1952 - 2007

# %%
print(df["country"].nunique())
# Out:
# 142

# %%
print(df["continent"].nunique())
# Out:
# 5

# %%
import matplotlib as plt
plt.bar(df["continent"],df["lifeExp"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_681/1785417537.py in <cell line: 0>()
#       1 import matplotlib as plt
# ----> 2 plt.bar(df["continent"],df["lifeExp"])
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     216         if name in props:
#     217             return props[name].__get__(instance)
# --> 218         raise AttributeError(
#     219             f"module {cls.__module__!r} has no attribute {name!r}")
#     220
#
# AttributeError: module 'matplotlib' has no attribute 'bar'
